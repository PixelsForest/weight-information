# %%
"""
3/10/2026

This is the plot for synergy claim in the manuscript.


3/11/2025
Two things to do:
1) Redesign the figure
2) Replot using the new data

1. Is it possible for panel A to have several histograms to be in one subplot?
2. Panel B for E[ln(MI/n)], panel C for ln(E[MI/n])?
3. Having the raw datapoints also plotted in panel B & C?

Side point: Information itself also follows log-normal distribution? Should I mention this point in the discussion or result section?
-- Only mentions as a side-observation. Do not add as a new finding, which may drag me into another long round of revision. 


histogram
ln MI/n ~ ln n
E[MI/n] ~ n

Why 19 connections for the last figure?
-- Fixed the code. Now 20


3/12/2026

By taking experiment, I find the significance of panel B (MI/n vs n) is contributed a lot due to the n=20 case.
If not including n=20 case, the slope would still be positive but needs more datapoints to be significant.

For panel C, if I only do regression on n=2~19 case, the slope is still always positive, but less significant.

My interpretation is the positive trend is always there but for n=2~19 it is relatively weak.

3/13/2026

Generated different sets of cov_different_20k dataset for synergy plot. They all show positive slope but none showed both significance
in mean and median for panel C.

Gladly, one of the dataset has a outlier simulation result at n=18 (outlier defined as in its median deviates strongly with median from 
other three simulations. Only  n=18 reach the standard of strong deviation by observation), after correcting it with group n=18 from another 
dataset, I replotted a new panel C.

"""
# Out:
# '\n3/10/2026\n\nThis is the plot for synergy claim in the manuscript.\n\n\n3/11/2025\nTwo things to do:\n1) Redesign the figure\n2) Replot using the new data\n\n1. Is it possible for panel A to have several histograms to be in one subplot?\n2. Panel B for E[ln(MI/n)], panel C for ln(E[MI/n])?\n3. Having the raw datapoints also plotted in panel B & C?\n\nSide point: Information itself also follows log-normal distribution? Should I mention this point in the discussion or result section?\n-- Only mentions as a side-observation. Do not add as a new finding, which may drag me into another long round of revision. \n\n\nhistogram\nln MI/n ~ ln n\nE[MI/n] ~ n\n\nWhy 19 connections for the last figure?\n-- Fixed the code. Now 20\n\n\n3/12/2026\n\nBy taking experiment, I find the significance of panel B (MI/n vs n) is contributed a lot due to the n=20 case.\nIf not including n=20 case, the slope would still be positive but needs more datapoints to be significant.\n\nFor panel C, if I only do r
# ...

# %%
#1234 123 124 134 234 12 13 14 23 24(barely) 34 12345 1245 1235 245 235 1245 2345 25 35 15 45(barely) 345 145

# %%
import sys
import os
sys.path.append(os.path.abspath(".."))

# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from scipy.stats import norm
from scipy.stats import ttest_ind
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
from sklearn.metrics import r2_score

# %%
from matplotlib.ticker import LogLocator
from matplotlib.colors import ListedColormap
import seaborn as sns
from scipy.stats import pearsonr
from sklearn.linear_model import LinearRegression
import statsmodels.api as sm

# %%
# make jupyter notebook plotting looks clearer
# doesn't change the figure size nor display size
# %config InlineBackend.figure_format = 'retina'

# %%
plt.rcParams['mathtext.fontset'] = 'cm'
plt.rcParams['font.family'] = 'serif'

# %%
import matplotlib.lines as mlines

def add_vertical_bracket(fig, ax_top, ax_bottom, text,
                         x_offset=0.015, arm=0.012,
                         text_offset=0.008, lw=1.5, fontsize=12):
    """
    Draw a vertical significance bracket to the right of two stacked axes.

    Parameters
    ----------
    fig : matplotlib.figure.Figure
    ax_top, ax_bottom : matplotlib axes
        The upper and lower axes to connect.
    text : str
        Text to display, e.g. r'$p < 10^{-5}$'
    x_offset : float
        How far to the right of the axes to place the bracket (figure coords).
    arm : float
        Horizontal arm length of the bracket (figure coords).
    text_offset : float
        Distance between bracket and text (figure coords).
    """
    bbox_top = ax_top.get_position()
    bbox_bottom = ax_bottom.get_position()

    # right side x position
    x = max(bbox_top.x1, bbox_bottom.x1) + x_offset

    # vertical span
    y_top = bbox_top.y0 + bbox_top.height * 0.4
    y_bottom = bbox_bottom.y0 + bbox_bottom.height * 0.6

    # vertical line
    fig.add_artist(mlines.Line2D(
        [x, x], [y_bottom, y_top],
        transform=fig.transFigure, color='black', lw=lw
    ))

    # top arm
    fig.add_artist(mlines.Line2D(
        [x - arm, x], [y_top, y_top],
        transform=fig.transFigure, color='black', lw=lw
    ))

    # bottom arm
    fig.add_artist(mlines.Line2D(
        [x - arm, x], [y_bottom, y_bottom],
        transform=fig.transFigure, color='black', lw=lw
    ))

    # text
    fig.text(
        x + text_offset, (y_top + y_bottom) / 2,
        text, rotation=90, va='center', ha='left', fontsize=fontsize
    )

# %%
# Set up the plotting area
fig = plt.figure(figsize=(6, 8))

# three panels
gs = fig.add_gridspec(3, 1)


#-------------------------- panel A ---------------------------------------------------

gsA = gs[0].subgridspec(3, 1)

axA1 = fig.add_subplot(gsA[0])
axA2 = fig.add_subplot(gsA[1])
axA3 = fig.add_subplot(gsA[2])

axes = [axA1, axA2, axA3]

# Load the data from the CSV file
df = pd.read_csv("generated_samples_20k_covdifferent_eigenmethod.csv")

# Get the unique values of 'n'
unique_n_values = [1, 4, 20]


# Define a color map
colors = plt.cm.magma(np.linspace(0.3, 0.8, len(unique_n_values))) #plt.get_cmap('tab10', len(unique_n_values))

# Set common xlim and ylim for all subplots
common_xlim = [np.min(np.log(df['MI'] / df['n'])), np.max(np.log(df['MI']/ df['n'])) + 0.1]
common_ylim = [-1e-4, 0.41]  # Assuming a reasonable log scale range; adjust as necessary

for ax in axes:
    ax.set_xlim(common_xlim)
    ax.set_ylim(common_ylim)

# list for preparing t test
data_ttest = []

# Plot histograms for MI/n for each unique 'n' value
for i, n_value in enumerate(unique_n_values):
    # Filter the DataFrame for the current 'n' value
    subset = df[df['n'] == n_value]

    # Calculate MI / n
    mi_over_n = subset['MI'] / subset['n']

    # take the log MI
    logmi_over_n = np.log(mi_over_n)

    # append for ttest
    data_ttest.append(logmi_over_n)

    # Plot the histogram on the corresponding subplot
    axes[i].hist(logmi_over_n, bins=100, range=common_xlim, alpha=0.6, color=colors[i], label=f'$n={n_value}$', density=True, log=False)  ########

    # Fit a normal distribution to the data
    mu, std = norm.fit(logmi_over_n)

    # Plot the PDF of the fitted normal distribution
    xmin, xmax = common_xlim[0], common_xlim[1]
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    axes[i].plot(x, p, color=colors[i], linewidth=1.5, ls='--', label="Mean = %.2f\nSD = %.2f" % (mu, std))

    # Add a vertical line at the mean (center) of the distribution
    axes[i].axvline(mu, color='k', linestyle='dashed', linewidth=1.5)

    # y ticks
    axes[i].set_yticks([0.0, 0.2, 0.4])

    # Add legends
    axes[i].legend(fontsize=9)

    # Customize the axes
    axes[i].spines['top'].set_visible(False)    # Remove top axis
    axes[i].spines['right'].set_visible(False)  # Remove right axis
    
    # Make left and bottom axes bolder
    axes[i].spines['left'].set_linewidth(1)
    ax.spines['bottom'].set_linewidth(1)

    # Disable x-ticks and x-tick labels for all but the bottom subplot
    if i < len(unique_n_values) - 1:
        axes[i].set_xticks([])
        axes[i].set_xticklabels([])
    

# do t - test between them
for i in range(len(unique_n_values) - 1):
    t_stat, p_value = ttest_ind(data_ttest[i], data_ttest[i+1])
    print(f"results for t test between group {unique_n_values[i]} and {unique_n_values[i+1]}", t_stat, p_value)

# Set a common title, xlabel, and ylabel for the entire figure
axA3.text(-3.2, -0.3, r'$\ln \frac{MI(\mathbf{w};\mathbf{x}^l)}{n}$', ha='center', fontsize=15)  # X-axis label
axA3.text(-10.5, 0.9, 'Probability Density', va='center', rotation='vertical', fontsize=10)  # Y-axis label

# add panel letter
axA1.text(
        -0.16, 3.7, 'A',
        transform=ax.transAxes,
        fontsize=16,
        fontname='Calibri',
        fontweight='bold',
        va='top',
        ha='left'
    )


# --------------------------- panel B ----------------------------------------

axB = fig.add_subplot(gs[1])
ax = axB


# Define the columns you want to analyze against MI
columns_to_analyze = ['n']
xlabel_names = ['n']
i=0
column='n'


# Log-transform the data
x = df[column].values
y = (df['MI'] / df['n']).values

#ind = np.where((x>0) & (x<16))[0] ##################
#x = x[ind] 
#y = y[ind]

# Scatter plot on log-log scale
sns.scatterplot(x=x, y=y, ax=ax, s=10, color='black', alpha=0.06, edgecolor=None)

# Pearson correlation coefficient and its p-value on log-log scale
corr, p_value = pearsonr(x, y)

# Linear regression using statsmodels
X = sm.add_constant(x)   # adds intercept term
Y = y
model = sm.OLS(Y, X).fit()

# Extract regression results
intercept = model.params[0]
slope = model.params[1]
R2 = model.rsquared

# 95% CI for intercept and slope
conf_int = model.conf_int(alpha=0.05)
intercept_ci = conf_int[0]
slope_ci = conf_int[1]

print(f'{column}:')
print(f'  slope = {slope:.4f}, 95% CI = [{slope_ci[0]:.4f}, {slope_ci[1]:.4f}];')
print(f'  intercept = {intercept:.4f}, 95% CI = [{intercept_ci[0]:.4f}, {intercept_ci[1]:.4f}];')
print(f'  R² = {R2:.4f};')
print(f'  slope p-value = {model.pvalues[1]:.4e}.')
print()

# Plot the regression line
X_pred = np.linspace(np.min(x), np.max(x), 100)
X_pred_with_const = sm.add_constant(X_pred)
Y_pred = model.predict(X_pred_with_const)

ax.plot(
    X_pred, Y_pred,
    color='red', linewidth=1.5, linestyle='--',
    label=(
        f'slope={slope:.5f}, 95% CI=[{slope_ci[0]:.5f}, {slope_ci[1]:.5f}], p={model.pvalues[1]:.2e};\n'
        f'intercept={intercept:.3f}.'
    )
)

pred = model.get_prediction(X_pred_with_const)
pred_ci = pred.conf_int()

ax.fill_between(
    X_pred,
    pred_ci[:,0],
    pred_ci[:,1],
    color='red',
    alpha=0.2
)

# see things on log scale
ax.set_yscale("log")

# Set titles and labels
ax.set_xlabel(fr'${xlabel_names[i]}$', fontsize=15)
ax.set_ylabel(r'$\frac{MI(\mathbf{w};\mathbf{x}^l)}{n}$', fontsize=16)

# set x ticks
ax.set_xticks(np.arange(1, 21))

# Add legend
leg = ax.legend(fontsize=9)
leg.set_in_layout(False)

# Improve the overall look
ax.spines['top'].set_visible(False)
ax.spines['right'].set_visible(False)

# Make left and bottom axes bolder
ax.spines['left'].set_linewidth(1)
ax.spines['bottom'].set_linewidth(1)

# Make the ticks on the left and bottom axes bolder and larger
ax.tick_params(axis='x', direction='out', length=4, width=1, labelsize=10)
ax.tick_params(axis='y', direction='out', length=4, width=1, labelsize=10)

# add panel letter
ax.text(
        -0.16, 1.02, 'B',
        transform=ax.transAxes,
        fontsize=16,
        fontname='Calibri',
        fontweight='bold',
        va='top',
        ha='left'
    )

# -------------------- panel C -----------------------------------------------------------------
axC = fig.add_subplot(gs[2])
ax = axC

# Get the unique values of 'n'
unique_n_values = sorted(df['n'].unique()) ############### 

# data for scatter
x = []
y = []

# for plot
x1 = []
y1 = []
y2 = []

#
data = []

# Read MI/n for each unique 'n' value
for i, n_value in enumerate(unique_n_values):
    # Filter the DataFrame for the current 'n' value
    subset = df[df['n'] == n_value]

    # Calculate MI / n
    mi_over_n = np.array(subset['MI'] / subset['n'])

    # append to data
    #x.extend([i+1] * len(logmi_over_n))
    #y.extend(logmi_over_n)
    x1.extend([i+1])
    y1.extend([np.mean(mi_over_n)]) 
    y2.extend([np.median(mi_over_n)])  
    #data.append(logmi_over_n)


ax1 = ax

colors = ['#1f77b4', '#2ca02c']

# scatter plot
ax1.scatter(x1, y1, color=colors[0])  # Green scatter plot
ax1.set_xlabel('$n$', fontsize=15)
ax1.set_xticks(range(1, 20 + 1))
ax1.set_ylabel(r'Mean of $\frac{MI(\mathbf{w};\mathbf{x}^l)}{n}$', color=colors[0], fontsize=12)

# Pearson correlation coefficient on log-log scale
corr, p_value = pearsonr(x1, y1)

# Linear regression
X = np.array(x1).reshape(-1, 1)
Y = np.array(y1).reshape(-1, 1)

# Linear regression using statsmodels
X = sm.add_constant(X)   # adds intercept term
Y = Y
model = sm.OLS(Y, X).fit()

# Extract regression results
intercept = model.params[0]
slope = model.params[1]
R2 = model.rsquared

# 95% CI for intercept and slope
conf_int = model.conf_int(alpha=0.05)

# Plot the regression line
X_pred = np.linspace(np.min(X) - 0.5, np.max(X) + 0.5, 100).reshape(-1, 1)
X_pred_with_const = sm.add_constant(X_pred)
Y_pred = model.predict(X_pred_with_const)
ax1.plot(X_pred, Y_pred, color=colors[0], linewidth=1.5, linestyle='--',
        label=f'slope={slope:.4f}, p={p_value:.2e};\nintercept={intercept:.2f}.')

# fill the ci prediction shadow
pred = model.get_prediction(X_pred_with_const)
pred_ci = pred.conf_int()

ax1.fill_between(
    X_pred[:,0],
    pred_ci[:,0],
    pred_ci[:,1],
    color=colors[0],
    alpha=0.2
)

# Customize the axes
ax1.spines['top'].set_visible(False)    # Remove top axis
ax1.spines['right'].set_visible(False)

ax1.spines['left'].set_color(colors[0])
ax1.tick_params(axis='y', colors=colors[0])
ax1.yaxis.label.set_color(colors[0])

# Make left and bottom axes bolder
ax1.spines['left'].set_linewidth(1.3)
ax1.spines['bottom'].set_linewidth(1)




# Create the second scatter plot (y2) with the right y-axis
# the std
ax2 = ax1.twinx()
ax2.scatter(x1, y2, color=colors[1])  # Blue scatter plot
ax2.set_ylabel(r'Median of $\frac{MI(\mathbf{w};\mathbf{x}^l)}{n}$', color=colors[1], fontsize=12)
ax2.tick_params(axis='y', labelcolor=colors[1])

# Pearson correlation coefficient on log-log scale
corr, p_value = pearsonr(x1, y2)

# Linear regression
X = np.array(x1).reshape(-1, 1)
Y = np.array(y2).reshape(-1, 1)


# Linear regression using statsmodels
X = sm.add_constant(X)   # adds intercept term
Y = Y
model = sm.OLS(Y, X).fit()

# Extract regression results
intercept = model.params[0]
slope = model.params[1]
R2 = model.rsquared

# 95% CI for intercept and slope
conf_int = model.conf_int(alpha=0.05)

print(slope, intercept, R2)

# Plot the regression line
X_pred = np.linspace(np.min(X) - 0.5, np.max(X) + 0.5, 100).reshape(-1, 1)
X_pred_with_const = sm.add_constant(X_pred)
Y_pred = model.predict(X_pred_with_const)
ax2.plot(X_pred, Y_pred, color=colors[1], linewidth=1.5, linestyle='--',
        label=f'slope={slope:.5f}, p={p_value:.2e};\nintercept={intercept:.2f}.')  ########################


# fill the ci prediction shadow
pred = model.get_prediction(X_pred_with_const)
pred_ci = pred.conf_int()

ax2.fill_between(
    X_pred[:,0],
    pred_ci[:,0],
    pred_ci[:,1],
    color=colors[1],
    alpha=0.2
)

# Customize the axes
ax2.spines['top'].set_visible(False)    # Remove top axis
ax2.spines['left'].set_visible(False)

ax2.spines['right'].set_color(colors[1])
ax2.tick_params(axis='y', colors=colors[1])
ax2.yaxis.label.set_color(colors[1])

# Make left and bottom axes bolder
ax2.spines['right'].set_linewidth(1.3)



# Add legends
ax1.legend(loc="lower right", fontsize=9)
ax2.legend(loc="upper left", fontsize=9)

# add panel letter
ax2.text(
        -0.16, 1.02, 'C',
        transform=ax.transAxes,
        fontsize=16,
        fontname='Calibri',
        fontweight='bold',
        va='top',
        ha='left'
    )

# --------------overall editing-------------------------------------
plt.tight_layout(pad=0.0, w_pad=0.00, h_pad=-0.0)

# p-value differences across histograms for panel A
add_vertical_bracket(fig, axA1, axA2, r'$p = 8.21 \times 10^{-5}$', x_offset=0.07, arm=0.012, lw=1)
add_vertical_bracket(fig, axA2, axA3, r'$p = 1.75 \times 10^{-2}$', x_offset=0.02, lw=1) 

#plt.tight_layout()
#plt.show()
plt.savefig("fig_4.pdf", bbox_inches="tight")
# Out:
# results for t test between group 1 and 4 -3.9458980413301696 8.219050065130603e-05
# results for t test between group 4 and 20 -2.3762557768191543 0.01758903974095216
# n:
#   slope = 0.0010, 95% CI = [0.0004, 0.0015];
#   intercept = 0.0955, 95% CI = [0.0893, 0.1018];
#   R² = 0.0007;
#   slope p-value = 3.7855e-04.
#
# 0.00025361567208169824 0.048943485798216765 0.24924895487940602

# %%
1/0.0008
# Out:
# 1250.0

# %%
np.median([1,2,3])
# Out:
# 2.0

# %%
a = np.array([1,2,3])
np.where((1<a) & (a<3))[:]
# Out:
# (array([1], dtype=int64),)

# %%
import pandas as pd

# 读取文件
df1 = pd.read_csv("generated_samples_20k_covdifferent_eigenmethod_batch1.csv")
df2 = pd.read_csv("generated_samples_20k_covdifferent_eigenmethod_batch2.csv")

# 删除 file2 中 n=18 的行
df2_clean = df2[df2["n"] != 18]

# 取出 file1 中 n=18 的行
rows_to_add = df1[df1["n"] == 18]

# 合并
combined = pd.concat([df2_clean, rows_to_add], ignore_index=True)

# 随机打乱
shuffled = combined.sample(frac=1).reset_index(drop=True)

# 保存
shuffled.to_csv("new_file.csv", index=False)

print("new_file.csv")
# Out:
# new_file.csv

# %%
df14 = df[df["n"] == 14]
np.min(df14)
# Out:
# 9.372354552505955e-06

# %%
0.013 / 14
# Out:
# 0.0009285714285714286

# %%
# Set up the plotting area
fig = plt.figure(figsize=(6, 5))

# three panels
gs = fig.add_gridspec(2, 1)


#-------------------------- panel A ---------------------------------------------------

gsA = gs[0].subgridspec(3, 1)

axA1 = fig.add_subplot(gsA[0])
axA2 = fig.add_subplot(gsA[1])
axA3 = fig.add_subplot(gsA[2])

axes = [axA1, axA2, axA3]

# Load the data from the CSV file
df = pd.read_csv("generated_samples_20k_covdifferent_eigenmethod.csv")

# Get the unique values of 'n'
unique_n_values = [1, 4, 20]


# Define a color map
colors = plt.cm.magma(np.linspace(0.3, 0.8, len(unique_n_values))) #plt.get_cmap('tab10', len(unique_n_values))

# Set common xlim and ylim for all subplots
common_xlim = [np.min(np.log(df['MI'] / df['n'])), np.max(np.log(df['MI']/ df['n'])) + 0.1]
common_ylim = [-1e-4, 0.41]  # Assuming a reasonable log scale range; adjust as necessary

for ax in axes:
    ax.set_xlim(common_xlim)
    ax.set_ylim(common_ylim)

# list for preparing t test
data_ttest = []

# Plot histograms for MI/n for each unique 'n' value
for i, n_value in enumerate(unique_n_values):
    # Filter the DataFrame for the current 'n' value
    subset = df[df['n'] == n_value]

    # Calculate MI / n
    mi_over_n = subset['MI'] / subset['n']

    # take the log MI
    logmi_over_n = np.log(mi_over_n)

    # append for ttest
    data_ttest.append(logmi_over_n)

    # Plot the histogram on the corresponding subplot
    axes[i].hist(logmi_over_n, bins=100, range=common_xlim, alpha=0.6, color=colors[i], label=f'$n={n_value}$', density=True, log=False)  ########

    # Fit a normal distribution to the data
    mu, std = norm.fit(logmi_over_n)

    # Plot the PDF of the fitted normal distribution
    xmin, xmax = common_xlim[0], common_xlim[1]
    x = np.linspace(xmin, xmax, 100)
    p = norm.pdf(x, mu, std)
    axes[i].plot(x, p, color=colors[i], linewidth=1.5, ls='--', label="Mean = %.2f\nSD = %.2f" % (mu, std))

    # Add a vertical line at the mean (center) of the distribution
    axes[i].axvline(mu, color='k', linestyle='dashed', linewidth=1.5)

    # y ticks
    axes[i].set_yticks([0.0, 0.2, 0.4])

    # Add legends
    axes[i].legend(fontsize=9)

    # Customize the axes
    axes[i].spines['top'].set_visible(False)    # Remove top axis
    axes[i].spines['right'].set_visible(False)  # Remove right axis
    
    # Make left and bottom axes bolder
    axes[i].spines['left'].set_linewidth(1)
    ax.spines['bottom'].set_linewidth(1)

    # Disable x-ticks and x-tick labels for all but the bottom subplot
    if i < len(unique_n_values) - 1:
        axes[i].set_xticks([])
        axes[i].set_xticklabels([])
    

# do t - test between them
for i in range(len(unique_n_values) - 1):
    t_stat, p_value = ttest_ind(data_ttest[i], data_ttest[i+1])
    print(f"results for t test between group {unique_n_values[i]} and {unique_n_values[i+1]}", t_stat, p_value)

# Set a common title, xlabel, and ylabel for the entire figure
axA3.text(-3.2, -0.3, r'$\ln \frac{MI(\mathbf{w};\mathbf{x}^l)}{n}$', ha='center', fontsize=15)  # X-axis label
axA3.text(-10.5, 0.9, 'Probability Density', va='center', rotation='vertical', fontsize=10)  # Y-axis label

# add panel letter
axA1.text(
        -0.16, 3.7, 'A',
        transform=ax.transAxes,
        fontsize=16,
        fontname='Calibri',
        fontweight='bold',
        va='top',
        ha='left'
    )


# -------------------- panel B -----------------------------------------------------------------
axB= fig.add_subplot(gs[1])
ax = axB

# Get the unique values of 'n'
unique_n_values = sorted(df['n'].unique()) ############### 

# data for scatter
x = []
y = []

# for plot
x1 = []
y1 = []
y2 = []

#
data = []

# Read MI/n for each unique 'n' value
for i, n_value in enumerate(unique_n_values):
    # Filter the DataFrame for the current 'n' value
    subset = df[df['n'] == n_value]

    # Calculate MI / n
    mi_over_n = np.array(subset['MI'] / subset['n'])

    # append to data
    #x.extend([i+1] * len(logmi_over_n))
    #y.extend(logmi_over_n)
    x1.extend([i+1])
    y1.extend([np.mean(mi_over_n)]) 
    y2.extend([np.median(mi_over_n)])  
    #data.append(logmi_over_n)


ax1 = ax

colors = ['#1f77b4', '#2ca02c']

# scatter plot
ax1.scatter(x1, y1, color=colors[0])  # Green scatter plot
ax1.set_xlabel('$n$', fontsize=15)
ax1.set_xticks(range(1, 20 + 1))
ax1.set_ylabel(r'Mean of $\frac{MI(\mathbf{w};\mathbf{x}^l)}{n}$', color=colors[0], fontsize=12)

# Pearson correlation coefficient on log-log scale
corr, p_value = pearsonr(x1, y1)

# Linear regression
X = np.array(x1).reshape(-1, 1)
Y = np.array(y1).reshape(-1, 1)

# Linear regression using statsmodels
X = sm.add_constant(X)   # adds intercept term
Y = Y
model = sm.OLS(Y, X).fit()

# Extract regression results
intercept = model.params[0]
slope = model.params[1]
R2 = model.rsquared

# 95% CI for intercept and slope
conf_int = model.conf_int(alpha=0.05)

# Plot the regression line
X_pred = np.linspace(np.min(X) - 0.5, np.max(X) + 0.5, 100).reshape(-1, 1)
X_pred_with_const = sm.add_constant(X_pred)
Y_pred = model.predict(X_pred_with_const)
ax1.plot(X_pred, Y_pred, color=colors[0], linewidth=1.5, linestyle='--',
        label=f'slope={slope:.4f}, p={p_value:.2e};\nintercept={intercept:.2f}.')

# fill the ci prediction shadow
pred = model.get_prediction(X_pred_with_const)
pred_ci = pred.conf_int()

ax1.fill_between(
    X_pred[:,0],
    pred_ci[:,0],
    pred_ci[:,1],
    color=colors[0],
    alpha=0.2
)

# Customize the axes
ax1.spines['top'].set_visible(False)    # Remove top axis
ax1.spines['right'].set_visible(False)

ax1.spines['left'].set_color(colors[0])
ax1.tick_params(axis='y', colors=colors[0])
ax1.yaxis.label.set_color(colors[0])

# Make left and bottom axes bolder
ax1.spines['left'].set_linewidth(1.3)
ax1.spines['bottom'].set_linewidth(1)




# Create the second scatter plot (y2) with the right y-axis
# the std
ax2 = ax1.twinx()
ax2.scatter(x1, y2, color=colors[1])  # Blue scatter plot
ax2.set_ylabel(r'Median of $\frac{MI(\mathbf{w};\mathbf{x}^l)}{n}$', color=colors[1], fontsize=12)
ax2.tick_params(axis='y', labelcolor=colors[1])

# Pearson correlation coefficient on log-log scale
corr, p_value = pearsonr(x1, y2)

# Linear regression
X = np.array(x1).reshape(-1, 1)
Y = np.array(y2).reshape(-1, 1)


# Linear regression using statsmodels
X = sm.add_constant(X)   # adds intercept term
Y = Y
model = sm.OLS(Y, X).fit()

# Extract regression results
intercept = model.params[0]
slope = model.params[1]
R2 = model.rsquared

# 95% CI for intercept and slope
conf_int = model.conf_int(alpha=0.05)

print(slope, intercept, R2)

# Plot the regression line
X_pred = np.linspace(np.min(X) - 0.5, np.max(X) + 0.5, 100).reshape(-1, 1)
X_pred_with_const = sm.add_constant(X_pred)
Y_pred = model.predict(X_pred_with_const)
ax2.plot(X_pred, Y_pred, color=colors[1], linewidth=1.5, linestyle='--',
        label=f'slope={slope:.5f}, p={p_value:.2e};\nintercept={intercept:.2f}.')  ########################


# fill the ci prediction shadow
pred = model.get_prediction(X_pred_with_const)
pred_ci = pred.conf_int()

ax2.fill_between(
    X_pred[:,0],
    pred_ci[:,0],
    pred_ci[:,1],
    color=colors[1],
    alpha=0.2
)

# Customize the axes
ax2.spines['top'].set_visible(False)    # Remove top axis
ax2.spines['left'].set_visible(False)

ax2.spines['right'].set_color(colors[1])
ax2.tick_params(axis='y', colors=colors[1])
ax2.yaxis.label.set_color(colors[1])

# Make left and bottom axes bolder
ax2.spines['right'].set_linewidth(1.3)



# Add legends
ax1.legend(loc="lower right", fontsize=9)
ax2.legend(loc="upper left", fontsize=9)

# add panel letter
ax2.text(
        -0.16, 1.02, 'B',
        transform=ax.transAxes,
        fontsize=16,
        fontname='Calibri',
        fontweight='bold',
        va='top',
        ha='left'
    )

# --------------overall editing-------------------------------------
plt.tight_layout(pad=0.0, w_pad=0.00, h_pad=-0.0)

# p-value differences across histograms for panel A
add_vertical_bracket(fig, axA1, axA2, r'$p = 8.21 \times 10^{-5}$', x_offset=0.07, arm=0.012, lw=1)
add_vertical_bracket(fig, axA2, axA3, r'$p = 1.75 \times 10^{-2}$', x_offset=0.02, lw=1) 

#plt.tight_layout()
#plt.show()
plt.savefig("fig_4.pdf", bbox_inches="tight")
# Out:
# results for t test between group 1 and 4 -3.9458980413301696 8.219050065130603e-05
# results for t test between group 4 and 20 -2.3762557768191543 0.01758903974095216
# 0.00025361567208169824 0.048943485798216765 0.24924895487940602
